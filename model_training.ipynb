# %%
import pandas as pd
import math
import sys
import os
import ast
import logging
import boto3
import random 

from scipy.io.wavfile import read as read_wav
import numpy as np
import torchaudio
import librosa

import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class AccentDataset(Dataset):
    def __init__(self,
                 dataset_path="/work/data/cv-corpus-7.0-2021-07-21/en/clips",
                 entries_path = "/work/data/cv-corpus-7.0-2021-07-21/en/train.tsv",
                 chosen_accents = ["us", "england", "indian", "canada",  "australia"],
                 audio_size=150000,
                 purpose="train",
                 train_valid_split=0.9,
                 **_):
        self.dataset_path = dataset_path
        self.audio_size = audio_size

        

        self.entries = pd.read_csv(f"{entries_path}", sep = None, engine = 'python')#.query(f"dataset == '{data_type}'")
        self.entries = self.entries[pd.notna(self.entries['accent'])]

        max_elements = min(self.entries["accent"].value_counts()[chosen_accents])
        balanced_entries = pd.DataFrame()
        for acc in chosen_accents:
            if purpose == "train":
                balanced_entries = balanced_entries.append(self.entries.query(f"accent == '{acc}'").iloc[:int(max_elements*train_valid_split)])
            elif purpose == "valid":
                balanced_entries = balanced_entries.append(self.entries.query(f"accent == '{acc}'").iloc[int(max_elements*train_valid_split):max_elements])

        self.entries = balanced_entries
        acc_map = self.entries["accent"].unique()
        self.entries = self.entries.sample(frac=1)
        ls = []
        for i in range(len(self.entries["accent"])):
            ls.append(np.where(self.entries["accent"].iloc[i] == acc_map)[0][0])
        self.entries['encoded_label'] = torch.nn.functional.one_hot(torch.tensor(ls)).split(1)

        self.bundle = torchaudio.pipelines.WAV2VEC2_BASE
        self.model = self.bundle.get_model().to("cuda:0")
        #self.entries["filepath"] = [os.path.join(dataset_path,"".join([os.path.basename(self.entries["filename"][i][:-3]),"mp3"])) for i in range(len(self.entries))]
        #self.entries["filepath"] = [os.path.join("/work/data/cv-corpus-7.0-2021-07-21/en/clips",self.entries["path"][i]) for i in range(len(self.entries))]
        self.cuda0 = torch.device('cuda:0')

    def __getitem__(self, index):
        entry = self.entries.iloc[index]


        waveform, sample_rate = torchaudio.load(os.path.join(self.dataset_path,entry["path"]))
        waveform = waveform.to("cuda:0")
        if sample_rate != self.bundle.sample_rate:
            waveform = torchaudio.functional.resample(waveform, sample_rate, self.bundle.sample_rate)

        if waveform.shape[1]< self.audio_size:
            waveform = F.pad(waveform, (0,self.audio_size - waveform.shape[1]), "constant", 0)
            start = 0
        else:
            start = random.choice(range(0,waveform.shape[1]-self.audio_size))
        waveform = waveform[:,start:start+self.audio_size]
        
        with torch.inference_mode():
            features, _ = self.model.extract_features(waveform)

        return torch.cat(features).to(self.cuda0), entry["encoded_label"].to(self.cuda0)[0]

    def __len__(self):
        return len(self.entries)

# %%
#s3 = boto3.resource('s3',aws_access_key_id="AKIAVFT6EWR3ZJ6J7RN4",
#    aws_secret_access_key="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")
#s3.Bucket("sagemaker-studio-355673093239-n7bauqajc2k").download_file("results/wav2vec2_fairseq_base_ls960.pth", 
#'/home/ubuntu/.cache/torch/hub/checkpoints/wav2vec2_fairseq_base_ls960.pth')

# %%
torch.cuda.empty_cache()

# %%
dataset = AccentDataset()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/8x/sm4wjnfx3q36gjxsbvws03_h0000gn/T/ipykernel_6640/4039359824.py in <module>
# ----> 1 dataset = AccentDataset()
#
# /var/folders/8x/sm4wjnfx3q36gjxsbvws03_h0000gn/T/ipykernel_6640/1460549150.py in __init__(self, dataset_path, entries_path, chosen_accents, audio_size, purpose, train_valid_split, **_)
#      13
#      14
# ---> 15         self.entries = pd.read_csv(f"{entries_path}", sep = None, engine = 'python')#.query(f"dataset == '{data_type}'")
#      16         self.entries = self.entries[pd.notna(self.entries['accent'])]
#      17
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/python_parser.py in __init__(self, f, **kwds)
#      94             self.data = cast(Iterator[str], f)
#      95         else:
# ---> 96             self._open_handles(f, kwds)
#      97             assert self.handles is not None
#      98             assert hasattr(self.handles.handle, "readline")
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     220         Let the readers open IOHandles after they are done with their potential raises.
#     221         """
# --> 222         self.handles = get_handle(
#     223             src,
#     224             "r",
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     699         if ioargs.encoding and "b" not in ioargs.mode:
#     700             # Encoding
# --> 701             handle = open(
#     702                 handle,
#     703                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/work/data/cv-corpus-7.0-2021-07-21/en/train.tsv'

# %%
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels=12, out_channels=640, kernel_size=8)
        self.fc1 = nn.Linear(9216, 640)
        self.rnn = nn.LSTM(
            input_size=640,
            hidden_size=480,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )
        self.dropout = nn.Dropout(0.1)
        self.fc2 = nn.Linear(960*468, 128)
        self.fc3 = nn.Linear(128, 5)

    def forward(self, x):
        x = x.permute(0,2,1,3).flatten(2)
        x = F.relu(self.fc1(x))
        x, _ = self.rnn(x)
        x = self.dropout(x)
        x = x.flatten(1)
        x = F.relu(self.fc2(x))
        x = F.log_softmax(self.fc3(x))
        return x

#     def forward(self, x):
# #         x = x.permute(0,2,1,3)#.flatten(2)
#         x = F.relu(self.conv1(x).flatten(2))
#         x, _ = self.rnn(x)
#         x = self.dropout(x)
#         x = x.flatten(1)
#         x = F.relu(self.fc2(x))
#         x = F.log_softmax(self.fc3(x))
#         return x


net = Net()

# %%
sample = torch.rand(size=(1,12, 468, 768))
net(sample)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/8x/sm4wjnfx3q36gjxsbvws03_h0000gn/T/ipykernel_6640/644689052.py in <module>
#       1 sample = torch.rand(size=(1,12, 468, 768))
# ----> 2 net(sample)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /var/folders/8x/sm4wjnfx3q36gjxsbvws03_h0000gn/T/ipykernel_6640/867333317.py in forward(self, x)
#      21     def forward(self, x):
#      22         x = x.permute(0,2,1,3).flatten(2)
# ---> 23         x = F.relu(self.fc1(x))
#      24         x, _ = self.rnn(x)
#      25         x = self.dropout(x)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#     101
#     102     def forward(self, input: Tensor) -> Tensor:
# --> 103         return F.linear(input, self.weight, self.bias)
#     104
#     105     def extra_repr(self) -> str:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1846     if has_torch_function_variadic(input, weight, bias):
#    1847         return handle_torch_function(linear, (input, weight, bias), input, weight, bias=bias)
# -> 1848     return torch._C._nn.linear(input, weight, bias)
#    1849
#    1850
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (468x9216 and 350821x640)

# %%
torch.cuda.empty_cache()

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=0.001)

# %%
from torch.utils.data import DataLoader

loader = DataLoader(dataset,32)
losses = []
for epoch in range(5):  # loop over the dataset multiple times

    running_loss = 0.0
    for i, data in enumerate(iter(loader), 0):
        # get the inputs; data is a list of [inputs, labels]
        inputs, labels = data

        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs)
        loss = criterion(outputs, labels.float())
        loss.backward()
        optimizer.step()
        losses.append(loss)
        print(loss)

        # print statistics
        running_loss += loss.item()
        if i % 1000 == 0:    # print every 2000 mini-batches
            print(f'[{epoch + 1}, {i + 1:5d}] loss: {running_loss / 2000:.3f}')
            running_loss = 0.0
            torch.save({
            'iter': i,
            'model_state_dict': net.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            
device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6577, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4067, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.7360, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5879, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6563, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5491, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5002, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(1.0376, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4714, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4744, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4021, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.7857, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6443, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5951, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6374, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4674, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5874, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6545, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6229, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.8002, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5431, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.3683, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5998, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4712, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.8147, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4779, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6255, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5910, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.3584, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.3998, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.8518, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5060, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.3968, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6429, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4398, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6702, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5333, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6431, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.9602, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4593, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4036, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5866, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6851, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5352, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.9460, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.4543, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.6580, device='cuda:0', grad_fn=<DivBackward1>)
# tensor(0.5495, device='cuda:0', grad_fn=<DivBackward1>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2385/2818542187.py in <module>
#       6
#       7     running_loss = 0.0
# ----> 8     for i, data in enumerate(iter(loader), 0):
#       9         # get the inputs; data is a list of [inputs, labels]
#      10         inputs, labels = data
#
# /work/miniconda/conda-groot/envs/sayso/lib/python3.9/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /work/miniconda/conda-groot/envs/sayso/lib/python3.9/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     559     def _next_data(self):
#     560         index = self._next_index()  # may raise StopIteration
# --> 561         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     562         if self._pin_memory:
#     563             data = _utils.pin_memory.pin_memory(data)
#
# /work/miniconda/conda-groot/envs/sayso/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /work/miniconda/conda-groot/envs/sayso/lib/python3.9/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      47     def fetch(self, possibly_batched_index):
#      48         if self.auto_collation:
# ---> 49             data = [self.dataset[idx] for idx in possibly_batched_index]
#      50         else:
#      51             data = self.dataset[possibly_batched_index]
#
# /tmp/ipykernel_2385/1460549150.py in __getitem__(self, index)
#      42
#      43
# ---> 44         waveform, sample_rate = torchaudio.load(os.path.join(self.dataset_path,entry["path"]))
#      45         waveform = waveform.to("cuda:0")
#      46         if sample_rate != self.bundle.sample_rate:
#
# /work/miniconda/conda-groot/envs/sayso/lib/python3.9/site-packages/torchaudio/backend/sox_io_backend.py in load(filepath, frame_offset, num_frames, normalize, channels_first, format)
#     150                 filepath, frame_offset, num_frames, normalize, channels_first, format)
#     151         filepath = os.fspath(filepath)
# --> 152     return torch.ops.torchaudio.sox_io_load_audio_file(
#     153         filepath, frame_offset, num_frames, normalize, channels_first, format)
#     154
#
# KeyboardInterrupt:

# %%
torch.save({
        'iter': i,
        'model_state_dict': net.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'losses': losses,
        }, f"checkpoints/model_e{epoch}_i{i}.pt")

# %%
def get_embeddings(net,x):
    x = x.permute(0,2,1,3).flatten(2)
    x = F.relu(net.fc1(x))
    x, _ = net.rnn(x)
    x = x.flatten(1)
    x = F.relu(net.fc2(x))
    return x

# %%
get_embeddings(net,dataset[2][0].reshape((1,12, 468, 768)))
# Out:
# tensor([[ 0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  9.0974,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  2.7690,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000, 11.3625,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000, 60.4875,
#           0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000,  0.0000]],
#        device='cuda:0', grad_fn=<ReluBackward0>)

# %%
import torchmetrics

acc = torchmetrics.Accuracy().to('cuda:0')
for i in range(len(dataset)):
    print(torch.argmax(net(dataset[0][0].reshape((1,12, 468, 768)))))
# Out:
# /tmp/ipykernel_2385/1906905800.py:27: UserWarning: Implicit dimension choice for log_softmax has been deprecated. Change the call to include dim=X as an argument.
#   x = F.log_softmax(self.fc3(x))
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(3, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2385/1376645728.py in <module>
#       3 acc = torchmetrics.Accuracy().to('cuda:0')
#       4 for i in range(len(dataset)):
# ----> 5     print(torch.argmax(net(dataset[0][0].reshape((1,12, 468, 768)))))
#
# /work/miniconda/conda-groot/envs/sayso/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /tmp/ipykernel_2385/1906905800.py in forward(self, x)
#      21         x = x.permute(0,2,1,3).flatten(2)
#      22         x = F.relu(self.fc1(x))
# ---> 23         x, _ = self.rnn(x)
#      24         x = self.dropout(x)
#      25         x = x.flatten(1)
#
# /work/miniconda/conda-groot/envs/sayso/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
#    1103         # Do not call functions when jit is used
#    1104         full_backward_hooks, non_full_backward_hooks = [], []
#
# /work/miniconda/conda-groot/envs/sayso/lib/python3.9/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     689         self.check_forward_args(input, hx, batch_sizes)
#     690         if batch_sizes is None:
# --> 691             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     692                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     693         else:
#
# KeyboardInterrupt:

# %%
dataset.entries
# Out:
#                                                 client_id  \
# 124538  ed07f16faa58a669b58de0207a11eb954d0076aa7b8c1c...
# 389642  2f561cb0b97147db51bc0ad72c0fab191a48ce2aab48a4...
# 630395  8449194e8b74b81d761d7a3786cdd5d099aff4f33737c7...
# 202405  4281670244e0d04d6bf3c10df6181337e8b00e3a0725e5...
# 343778  f12a988e9d251485294edec8740dfec779b45127c1bb06...
# ...                                                   ...
# 321223  68caafdf147c42aa78002abb9c2ac5b61f36b8c8ec4773...
# 173182  dcda0922112645666327ffc15a63c2908424fa970ddbed...
# 584365  cbbf0b4896d532ed8bfad4d3a82e356c699d62cc1f88fa...
# 160927  73ddd9cb79e56d3edfa1902dac26767323ad23e4418538...
# 210407  619f08dd806f9ccce744ffcfed4c1f5dd587313dd11d57...
#
#                                 path  \
# 124538  common_voice_en_19638562.mp3
# 389642  common_voice_en_21090775.mp3
# 630395  common_voice_en_22937498.mp3
# 202405  common_voice_en_19667270.mp3
# 343778  common_voice_en_21942909.mp3
# ...                              ...
# 321223  common_voice_en_23664990.mp3
# 173182  common_voice_en_22024639.mp3
# 584365  common_voice_en_21638312.mp3
# 160927  common_voice_en_20994723.mp3
# 210407    common_voice_en_214303.mp3
#
#                                                  sentence  up_votes  \
# 124538  His areas of specialty include epistemology, K...         3
# 389642  The lyrics are largely based on Milton Ager's ...         2
# 630395  The sounds that are used today were formed in ...         2
# 202405  It consisted of three counties - Washington, G...         2
# 343778  Before moving into writing, he worked as an at...         2
# ...                                                   ...       ...
# 321223  Nevertheless, Bahloo is sometimes seen walking...         2
# 173182  Certain functions of the Council, however, rem...         2
# 584365  While it is less efficient than the general al...         2
# 160927    Susan knows where the gold is, but can't speak.         2
# 210407     A wakeboarder is performing a trick on a rail.         2
#
#         down_votes        age  gender     accent locale  segment  \
# 124538           0      teens    male         us     en      NaN
# 389642           0   twenties    male     canada     en      NaN
# 630395           0   twenties  female  australia     en      NaN
# 202405           0   twenties    male    england     en      NaN
# 343778           0   twenties    male     indian     en      NaN
# ...            ...        ...     ...        ...    ...      ...
# 321223           0   twenties    male    england     en      NaN
# 173182           0  seventies  female         us     en      NaN
# 584365           0   twenties    male  australia     en      NaN
# 160927           0   twenties  female    england     en      NaN
# 210407           0   fourties    male     indian     en      NaN
#
#                                             encoded_label
# 124538  [[tensor(1), tensor(0), tensor(0), tensor(0), ...
# 389642  [[tensor(0), tensor(0), tensor(0), tensor(1), ...
# 630395  [[tensor(0), tensor(0), tensor(0), tensor(0), ...
# 202405  [[tensor(0), tensor(1), tensor(0), tensor(0), ...
# 343778  [[tensor(0), tensor(0), tensor(1), tensor(0), ...
# ...                                                   ...
# 321223  [[tensor(0), tensor(1), tensor(0), tensor(0), ...
# 173182  [[tensor(1), tensor(0), tensor(0), tensor(0), ...
# 584365  [[tensor(0), tensor(0), tensor(0), tensor(0), ...
# 160927  [[tensor(0), tensor(1), tensor(0), tensor(0), ...
# 210407  [[tensor(0), tensor(0), tensor(1), tensor(0), ...
#
# [129065 rows x 11 columns]
